# %% [markdown]
# # Libreta 101 - Introducción a ML/DL
#
# Alan Badillo Salas
#
# ...

# %%
# %pip install numpy pandas matplotlib seaborn

# %%
import numpy
import pandas

from matplotlib import pyplot
import seaborn

# %% [markdown]
# ## Fase 1 - Construcción del Cubo de Datos
#
# 1. Adquirir el Conjunto de Datos
# 2. Construir los ejes de análisis (ejes de datos / series de datos)
# 3. Diseñar el Cubo de Datos (convertir cada eje de datos en series numéricas)
# 4. (Opcional) Visualizar y analizar el Cubo de Datos

# %%
# local: conjuntos/student_habits_performance.csv
# git: https://github.com/dragonnomada/ia-cic-abril-2026/blob/main/conjuntos/student_habits_performance.csv?raw=true
url = "https://raw.githubusercontent.com/dragonnomada/ia-cic-abril-2026/refs/heads/main/conjuntos/student_habits_performance.csv"

students = pandas.read_csv(url)

students.head(10)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
# 5      S1005   24    Male                  7.2                 1.3
# 6      S1006   21  Female                  5.6                 1.5
# 7      S1007   21  Female                  4.3                 1.0
# 8      S1008   23  Female                  4.4                 2.2
# 9      S1009   18  Female                  4.8                 3.1
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
# 5            0.0            No                   82.9          7.4
# 6            1.4           Yes                   85.8          6.5
# 7            2.0           Yes                   77.7          4.6
# 8            1.7            No                  100.0          7.1
# 9            1.3            No                   95.4          7.5
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
# 5         Fair                   1                   Master          Average
# 6         Good                   2                   Master             Poor
# 7         Fair                   0                 Bachelor          Average
# 8         Good                   3                 Bachelor             Good
# 9         Good                   5                 Bachelor             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4
# 5                     4                            No       100.0
# 6                     4                            No        89.8
# 7                     8                            No        72.6
# 8                     1                            No        78.9
# 9                    10                           Yes       100.0

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
#  12  internet_quality               1000 non-null   object
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   object
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 125.1+ KB

# %%
e1 = students["age"]
e2 = students["gender"]
e3 = students["study_hours_per_day"]
e4 = students["social_media_hours"]
e5 = students["netflix_hours"]
e6 = students["part_time_job"]
e7 = students["attendance_percentage"]
e8 = students["sleep_hours"]
e9 = students["diet_quality"]
e10 = students["exercise_frequency"]
e11 = students["parental_education_level"]
e12 = students["internet_quality"]
e13 = students["mental_health_rating"]
e14 = students["extracurricular_participation"]
e15 = students["exam_score"]

# %%
e1.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
e1.describe()
# Out:
# count    1000.0000
# mean       20.4980
# std         2.3081
# min        17.0000
# 25%        18.7500
# 50%        20.0000
# 75%        23.0000
# max        24.0000
# Name: age, dtype: float64

# %%
e1.plot.box(vert=False)
# Out:
# <Axes: >

# %%
e2.describe()
# Out:
# count       1000
# unique         3
# top       Female
# freq         481
# Name: gender, dtype: object

# %%
e2.value_counts()
# Out:
# gender
# Female    481
# Male      477
# Other      42
# Name: count, dtype: int64

# %%
e2.value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
ejes = [e1, e2, e3, e4, e5, e6, e7, e8, e9, e10, e11, e12, e13, e14, e15]

for i, eje in enumerate(ejes):
    print(f"e{i + 1} -", eje.name)
    print("-" * 40)
    print(eje.describe())
    print("-" * 40)
    print()
# Out:
# e1 - age
# ----------------------------------------
# count    1000.0000
# mean       20.4980
# std         2.3081
# min        17.0000
# 25%        18.7500
# 50%        20.0000
# 75%        23.0000
# max        24.0000
# Name: age, dtype: float64
# ----------------------------------------
#
# e2 - gender
# ----------------------------------------
# count       1000
# unique         3
# top       Female
# freq         481
# Name: gender, dtype: object
# ----------------------------------------
#
# e3 - study_hours_per_day
# ----------------------------------------
# count    1000.00000
# mean        3.55010
# std         1.46889
# min         0.00000
# 25%         2.60000
# 50%         3.50000
# 75%         4.50000
# max         8.30000
# Name: study_hours_per_day, dtype: float64
# ----------------------------------------
#
# e4 - social_media_hours
# ----------------------------------------
# count    1000.000000
# mean        2.505500
# std         1.172422
# min         0.000000
# 25%         1.700000
# 50%         2.500000
# 75%         3.300000
# max         7.200000
# Name: social_media_hours, dtype: float64
# ----------------------------------------
#
# e5 - netflix_hours
# ----------------------------------------
# count    1000.000000
# mean        1.819700
# std         1.075118
# min         0.000000
# 25%         1.000000
# 50%         1.800000
# 75%         2.525000
# max         5.400000
# Name: netflix_hours, dtype: float64
# ----------------------------------------
#
# e6 - part_time_job
# ----------------------------------------
# count     1000
# unique       2
# top         No
# freq       785
# Name: part_time_job, dtype: object
# ----------------------------------------
#
# e7 - attendance_percentage
# ----------------------------------------
# count    1000.000000
# mean       84.131700
# std         9.399246
# min        56.000000
# 25%        78.000000
# 50%        84.400000
# 75%        91.025000
# max       100.000000
# Name: attendance_percentage, dtype: float64
# ----------------------------------------
#
# e8 - sleep_hours
# ----------------------------------------
# count    1000.000000
# mean        6.470100
# std         1.226377
# min         3.200000
# 25%         5.600000
# 50%         6.500000
# 75%         7.300000
# max        10.000000
# Name: sleep_hours, dtype: float64
# ----------------------------------------
#
# e9 - diet_quality
# ----------------------------------------
# count     1000
# unique       3
# top       Fair
# freq       437
# Name: diet_quality, dtype: object
# ----------------------------------------
#
# e10 - exercise_frequency
# ----------------------------------------
# count    1000.000000
# mean        3.042000
# std         2.025423
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max         6.000000
# Name: exercise_frequency, dtype: float64
# ----------------------------------------
#
# e11 - parental_education_level
# ----------------------------------------
# count             909
# unique              3
# top       High School
# freq              392
# Name: parental_education_level, dtype: object
# ----------------------------------------
#
# e12 - internet_quality
# ----------------------------------------
# count     1000
# unique       3
# top       Good
# freq       447
# Name: internet_quality, dtype: object
# ----------------------------------------
#
# e13 - mental_health_rating
# ----------------------------------------
# count    1000.000000
# mean        5.438000
# std         2.847501
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         8.000000
# max        10.000000
# Name: mental_health_rating, dtype: float64
# ----------------------------------------
#
# e14 - extracurricular_participation
# ----------------------------------------
# count     1000
# unique       2
# top         No
# freq       682
# Name: extracurricular_participation, dtype: object
# ----------------------------------------
#
# e15 - exam_score
# ----------------------------------------
# count    1000.000000
# mean       69.601500
# std        16.888564
# min        18.400000
# 25%        58.475000
# 50%        70.500000
# 75%        81.325000
# max       100.000000
# Name: exam_score, dtype: float64
# ----------------------------------------

# %%
e2.unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
e6.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
e9.unique()
# Out:
# array(['Fair', 'Good', 'Poor'], dtype=object)

# %%
e11.unique()
# Out:
# array(['Master', 'High School', 'Bachelor', nan], dtype=object)

# %%
x1 = e1 # numérico 17-24
x2 = (e2 == "Male").astype(int) # numérico 0,1
x2.name = "is_male"
x3 = (e2 == "Other").astype(int) # numérico 0,1
x3.name = "is_other"
x4 = e3
x5 = e4
x6 = e5
x7 = (e6 == "Yes").astype(int) # numérico 0,1
x7.name = "part_time_job"
x8 = e7
x9 = e8
# dummies
# x10 = (e9 == "Poor").astype(int) # numérico 0,1
# x11 = (e9 == "Good").astype(int) # numérico 0,1
x10 = e9.map({
    "Poor": -1,
    "Fair": 0,
    "Good": 1,
})
x11 = e10
x12 = e11.map({
    "High School": 1,
    "Bachelor": 2,
    "Master": 4,
}).fillna(1.5)
x13 = e13
x14 = (e14 == "Yes").astype(int)
x14.name = "extracurricular"

y = e15

# %%
X = pandas.DataFrame([
    x1, x2, x3,
    x4, x5, x6,
    x7, x8, x9,
    x10, x11, x12,
    x13, x14,
]).T

# %%
X
# Out:
#       age  is_male  is_other  study_hours_per_day  social_media_hours  \
# 0    23.0      0.0       0.0                  0.0                 1.2
# 1    20.0      0.0       0.0                  6.9                 2.8
# 2    21.0      1.0       0.0                  1.4                 3.1
# 3    23.0      0.0       0.0                  1.0                 3.9
# 4    19.0      0.0       0.0                  5.0                 4.4
# ..    ...      ...       ...                  ...                 ...
# 995  21.0      0.0       0.0                  2.6                 0.5
# 996  17.0      0.0       0.0                  2.9                 1.0
# 997  20.0      1.0       0.0                  3.0                 2.6
# 998  24.0      1.0       0.0                  5.4                 4.1
# 999  19.0      0.0       0.0                  4.3                 2.9
#
#      netflix_hours  part_time_job  attendance_percentage  sleep_hours  \
# 0              1.1            0.0                   85.0          8.0
# 1              2.3            0.0                   97.3          4.6
# 2              1.3            0.0                   94.8          8.0
# 3              1.0            0.0                   71.0          9.2
# 4              0.5            0.0                   90.9          4.9
# ..             ...            ...                    ...          ...
# 995            1.6            0.0                   77.0          7.5
# 996            2.4            1.0                   86.0          6.8
# 997            1.3            0.0                   61.9          6.5
# 998            1.1            1.0                  100.0          7.6
# 999            1.9            0.0                   89.4          7.1
#
#      diet_quality  exercise_frequency  parental_education_level  \
# 0             0.0                 6.0                       4.0
# 1             1.0                 6.0                       1.0
# 2            -1.0                 1.0                       1.0
# 3            -1.0                 4.0                       4.0
# 4             0.0                 3.0                       4.0
# ..            ...                 ...                       ...
# 995           0.0                 2.0                       1.0
# 996          -1.0                 1.0                       1.0
# 997           1.0                 5.0                       2.0
# 998           0.0                 0.0                       2.0
# 999           1.0                 2.0                       2.0
#
#      mental_health_rating  extracurricular
# 0                     8.0              1.0
# 1                     8.0              0.0
# 2                     1.0              0.0
# 3                     1.0              1.0
# 4                     1.0              0.0
# ..                    ...              ...
# 995                   6.0              1.0
# 996                   6.0              1.0
# 997                   9.0              1.0
# 998                   1.0              0.0
# 999                   8.0              0.0
#
# [1000 rows x 14 columns]

# %% [markdown]
# $\hat{y} = \beta_0 + \beta_1 \cdot x_1 + \beta_2 \cdot x_2 + \ldots + \beta_k \cdot x_k$

# %% [markdown]
# $loss = \sum (y_i - \hat{y}_i)^2$

# %% [markdown]
# *MSE* - Mean Square Error
#
# *RMSE* - Root Mean Square Error
#
# *MAE* - Mean Absolute Error
